# %% [markdown]
# # Mini-Project on COVID19 Data Analysis using Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import folium
import plotly as py

# %% [markdown]
# <h3>Section 1: COVID19 dataset <text>&</text> Libraries </h3>

# %% [markdown]
# <div class="alert alert-info">
#     <h8>Visualize the data for <b>India</b>, <b>China</b> and <b>US</b> countries<h8>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Load the data frim time series covid 19 confirmed cases</b>
# </div>

# %%
df = pd.read_csv('time_series_covid_19_confirmed.csv')

# %% [markdown]
# <div class="alert alert-info">
# <b>Dropping the lat and long columns</b>
# </div>

# %%
df.drop(['Lat', 'Long'],axis=1,inplace=True)

# %%
dates = df.columns[4:]
renaming_column_date = df.melt(
    id_vars=['Province/State', 'Country/Region'],
    value_vars=dates,
    var_name='Date'
)

# %% [markdown]
# <div class="alert alert-info">
# <b>Conversion of the date from 1/24/2020 to 2020-01-24</b>
# </div>

# %%
renaming_column_date['Date'] = pd.to_datetime(renaming_column_date['Date'])

# %%
country_wise_count = renaming_column_date.groupby(['Country/Region'],as_index=False).agg({'value': 'sum'})

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>This is used to find the spike happended worldwide for covid 19 confirmed cases:</b>
# </div>

# %%
sns.set();
country_wise_count.plot(figsize=(16,5)).autoscale(axis='x',tight=True);

# %% [markdown]
# <div class="alert alert-dark">
# <h2>Approaches followed to Visualizing the data across 3 countries: India, China and US</h2>
#   <p>Method followed was:</p>
#   <ul>
#     <li>Changed the location of date from column header to row wise
#         <ul>
#             <li>Used melt</li>
#         </ul>
#       </li>
#     <li>Conversion of data from MM/DD/YYYY to YYYY-MM-DD</li>
#     <li>Grouped the country wise list as we were having statewise data</li>
#     <li>Used diff() method to get proper plot instead of going with traditional way that is to use only plot() which give us plain <b>plot</b> </li>
#   </ul>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><strong>India COVID growth in span of months</strong></b>
# </div>

# %%
sns.set()
covid_confirmed_cases = renaming_column_date[renaming_column_date['Country/Region'] == 'India']
confirmed_cases_India = covid_confirmed_cases.groupby(['Date']).agg({'value': 'sum'})
confirmed_cases_India['value'].diff().plot(figsize=(16,4), title='India Confirmed Cases').autoscale(axis='x',tight=True);

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><strong>US</strong> COVID growth in span of months</b>
# </div>

# %%
sns.set()
covid_confirmed_cases = renaming_column_date[renaming_column_date['Country/Region'] == 'US']
confirmed_cases_US = covid_confirmed_cases.groupby(['Date']).agg({'value': 'sum'})
confirmed_cases_US['value'].diff().plot(figsize=(16,4), title='US Confirmed Cases').autoscale(axis='x',tight=True);

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><strong>CHINA</strong> COVID growth in span of months</b>
# </div>

# %%
sns.set()
covid_confirmed_cases = renaming_column_date[renaming_column_date['Country/Region'] == 'China']
confirmed_cases_China = covid_confirmed_cases.groupby(['Date']).agg({'value': 'sum'})
confirmed_cases_China['value'].diff().plot(figsize=(18,4), title='China Confirmed Cases').autoscale(axis='x',tight=True);

# %% [markdown]
# <h3>Section 2: Finding a good Measure</h3>

# %%
covid_data_agg = df.groupby(['Country/Region']).sum()
covid_data_agg
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  8/3/20  8/4/20  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...   36747   36782
# Albania                   0        0        0        0  ...    5620    5750
# Algeria                   0        0        0        0  ...   31972   32504
# Andorra                   0        0        0        0  ...     937     939
# Angola                    0        0        0        0  ...    1280    1344
# ...                     ...      ...      ...      ...  ...     ...     ...
# West Bank and Gaza        0        0        0        0  ...   12541   12770
# Western Sahara            0        0        0        0  ...      10      10
# Yemen                     0        0        0        0  ...    1734    1760
# Zambia                    0        0        0        0  ...    6580    6793
# Zimbabwe                  0        0        0        0  ...    4075    4221
#
#                     8/5/20  8/6/20  8/7/20  8/8/20  8/9/20  8/10/20  8/11/20  \
# Country/Region
# Afghanistan          36829   36896   37015   37054   37054    37162    37269
# Albania               5889    6016    6151    6275    6411     6536     6676
# Algeria              33055   33626   34155   34693   35160    35712    36204
# Andorra                939     944     955     955     955      963      963
# Angola                1395    1483    1538    1572    1672     1679     1735
# ...                    ...     ...     ...     ...     ...      ...      ...
# West Bank and Gaza   13065   13398   13722   13928   14208    14510    14875
# Western Sahara          10      10      10      10      10       10       10
# Yemen                 1763    1768    1796    1797    1804     1832     1831
# Zambia                7022    7164    7486    7903    8085     8210     8275
# Zimbabwe              4221    4339    4451    4575    4649     4748     4818
#
#                     8/12/20
# Country/Region
# Afghanistan           37345
# Albania                6817
# Algeria               36699
# Andorra                 977
# Angola                 1762
# ...                     ...
# West Bank and Gaza    15184
# Western Sahara           10
# Yemen                  1841
# Zambia                 8501
# Zimbabwe               4893
#
# [188 rows x 204 columns]

# %% [markdown]
# <div class="alert alert-info">
# <b>India highest spike as per the data set</b>
# </div>

# %%
max_inc_India = covid_data_agg.loc['India'].diff().max()
print('Highest Day spike for India: ' + str(max_inc_India))
# Out:
# Highest Day spike for India: 66999.0

# %% [markdown]
# <div class="alert alert-info">
# <b>US's highest spike as per the data set</b>
# </div>

# %%
max_inc_US = covid_data_agg.loc['US'].diff().max()
print('Highest Day spike for USA : ' + str(max_inc_US))
# Out:
# Highest Day spike for USA : 77255.0

# %% [markdown]
# <div class="alert alert-info">
# <b>China's highest spike as per the data set</b>
# </div>

# %%
max_inc_China = covid_data_agg.loc['China'].diff().max()
print('Highest Day spike for China : ' + str(max_inc_China))
# Out:
# Highest Day spike for China : 15136.0

# %% [markdown]
# <div class="alert alert-info">
# <b>Plotting the Infection Rate in India</b>
# </div>

# %%
max_inc_India = covid_data_agg.loc['India'].diff().plot(figsize=(15,4), title='India Confirmed Cases').autoscale(axis='x',tight=True);

# %% [markdown]
# <h4>A. Maximum <b>‘Infection Rate’</b> for each country and store it in a new column named ‘max_infection_rate’</h4>

# %% [markdown]
# <div class="alert alert-dark">
# <h4>Approaches followed for adding a new column to the existing Data Sets</h4>
#   <p>Method followed was:</p>
#   <ul>
#     <li>Finding out the list of unique countries from the data by using:
#         <ul>
#             <li>unique() - method</li>
#         </ul>
#       </li>
#     <li>Creating an empty list</li>
#     <li>Iterating everything in a loop by using the list</li>
#     <li>Appending with created empty list and stroing the values under colums</li>
#   </ul>
# </div>

# %%
countries = list(df['Country/Region'].unique())
max_infections = []
for c in countries: 
    max_infections.append(covid_data_agg.loc[c].diff().max())

# Add to the data
covid_data_agg['max_infection_rate'] = max_infections

# %%
covid_data_agg
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  8/4/20  8/5/20  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...   36782   36829
# Albania                   0        0        0        0  ...    5750    5889
# Algeria                   0        0        0        0  ...   32504   33055
# Andorra                   0        0        0        0  ...     939     939
# Angola                    0        0        0        0  ...    1344    1395
# ...                     ...      ...      ...      ...  ...     ...     ...
# West Bank and Gaza        0        0        0        0  ...   12770   13065
# Western Sahara            0        0        0        0  ...      10      10
# Yemen                     0        0        0        0  ...    1760    1763
# Zambia                    0        0        0        0  ...    6793    7022
# Zimbabwe                  0        0        0        0  ...    4221    4221
#
#                     8/6/20  8/7/20  8/8/20  8/9/20  8/10/20  8/11/20  8/12/20  \
# Country/Region
# Afghanistan          36896   37015   37054   37054    37162    37269    37345
# Albania               6016    6151    6275    6411     6536     6676     6817
# Algeria              33626   34155   34693   35160    35712    36204    36699
# Andorra                944     955     955     955      963      963      977
# Angola                1483    1538    1572    1672     1679     1735     1762
# ...                    ...     ...     ...     ...      ...      ...      ...
# West Bank and Gaza   13398   13722   13928   14208    14510    14875    15184
# Western Sahara          10      10      10      10       10       10       10
# Yemen                 1768    1796    1797    1804     1832     1831     1841
# Zambia                7164    7486    7903    8085     8210     8275     8501
# Zimbabwe              4339    4451    4575    4649     4748     4818     4893
#
#                     max_infection_rate
# Country/Region
# Afghanistan                      915.0
# Albania                          141.0
# Algeria                          675.0
# Andorra                           79.0
# Angola                           100.0
# ...                                ...
# West Bank and Gaza               501.0
# Western Sahara                     4.0
# Yemen                            116.0
# Zambia                           915.0
# Zimbabwe                         490.0
#
# [188 rows x 205 columns]

# %% [markdown]
# <h5>Create a New Data Frame name ‘Corona Data’ with ‘Country/Region’ as an index and 'max_infection_rate’ as a column</h5>

# %%
Corona_Data = pd.DataFrame(covid_data_agg['max_infection_rate'])
Corona_Data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  915.0
# Albania                      141.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                       100.0

# %%
Corona_Data.tail()
# Out:
#                     max_infection_rate
# Country/Region
# West Bank and Gaza               501.0
# Western Sahara                     4.0
# Yemen                            116.0
# Zambia                           915.0
# Zimbabwe                         490.0

# %% [markdown]
# # Section 3: World happiness report dataset

# %% [markdown]
# <div class="alert alert-info">
# <b>Load the data sets of worldwise happiness report</b>
# </div>

# %%
happiness_data = pd.read_csv('worldwide_happiness_report.csv')
happiness_data.shape
# Out:
# (156, 9)

# %% [markdown]
# <div class="alert alert-info">
# <b>Drop 'Overall rank', 'Score', 'Generosity', 'Perceptions of corruption' columns. Set ‘Country or region’ column as Index</b>
# </div>

# %%
dropping_cols = ['Overall rank', 'Score', 'Generosity', 'Perceptions of corruption']
# Drop the useless cols 
happiness_data.drop(dropping_cols, inplace=True, axis=1)
happiness_data
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# 2                      1.028                         0.603
# 3                      1.026                         0.591
# 4                      0.999                         0.557
# ..                       ...                           ...
# 151                    0.614                         0.555
# 152                    0.499                         0.417
# 153                    0.361                         0.000
# 154                    0.105                         0.225
# 155                    0.295                         0.010
#
# [156 rows x 5 columns]

# %% [markdown]
# <h5>Task:Create a DataFrame named ‘data’ by merging ‘happiness_report’ with ‘Corona Data’ and find correlation among all variables </h5>

# %% [markdown]
# <div class="alert alert-info">
# <b>Creating a data frame of data with happiness report with created corona data</b>
# </div>

# %%
happiness_data.set_index(['Country or region'], inplace=True)

# %%
data = Corona_Data.join(happiness_data,how='inner')
data
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               915.0           0.350           0.517
# Albania                   141.0           0.947           0.848
# Algeria                   675.0           1.002           1.160
# Argentina                7663.0           1.092           1.432
# Armenia                   771.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                1150.0           0.960           1.427
# Vietnam                    50.0           0.741           1.346
# Yemen                     116.0           0.287           1.163
# Zambia                    915.0           0.578           1.058
# Zimbabwe                  490.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
# ...                              ...                           ...
# Venezuela                      0.805                         0.154
# Vietnam                        0.851                         0.543
# Yemen                          0.463                         0.143
# Zambia                         0.426                         0.431
# Zimbabwe                       0.433                         0.361
#
# [144 rows x 5 columns]

# %% [markdown]
# <div class="alert alert-info">
# <b>Find correlation among all variables</b>
# </div>

# %%
x = data['Social support']
y = data['max_infection_rate']

sns.scatterplot(x, np.log(y))

# %%
sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# # Section 4: Visualization using Folium Map Task:

# %% [markdown]
# ##### Task: Add the Latitude & Longitude information of countries in ‘data’ and Visualize it using Folium world map

# %%
covid_data_2 = pd.read_csv('covid_19_confirmed_dataset.csv')

# %%
group_c = covid_data_2.groupby('Country/Region').sum()
df_lo = pd.DataFrame(group_c) 
df_location_co = df_lo[['Lat', 'Long']]

# %%
data= df_location_co.join(happiness_data,how='inner')

# %%
map_world = folium.Map(location=[data['Lat'].mean(), data['Long'].mean()], tiles = "Stamen Toner", zoom_start = 2)

for lat, lng, social, healthy,GDP,freedom in zip(data['Lat'], data['Long'],data['Social support'],data['Healthy life expectancy'],data['GDP per capita'],data['Freedom to make life choices']):
    folium.CircleMarker(
        location = [lat, lng],
        radius=3,
        tooltip = 
        "<li><b>Social support: </b>"+str(social)+"</li>"+
        "<li><b>Healthy life expectancy: </b>"+str(healthy)+"</li>"+
        "<li><b>GDP: </b>"+str(GDP)+"</li>"+
        "<li><b>Freedom: </b>"+str(freedom)+"</li>"
        ,        
        fill=True,
        color='Blue',
        fill_color='Yellow',
        fill_opacity=0.6
        ).add_to(map_world)

#  display interactive map
map_world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_world.save('world_data.html')
# Import the Folium interactive html file


from IPython.display import HTML
HTML('<iframe src=world_data.html width=990 height=650></iframe>')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=world_data.html width=990 height=650></iframe>

# %% [markdown]
# <div class="alert alert-info">
# <b>Another Approach</b>
# </div>

# %%
world_map = folium.Map(location=[data['Lat'].mean(),data['Long'].mean()],tiles='cartodbpositron',zoom_start=2)
for i in range(0,len(data[data['GDP per capita']>0].index)):
    folium.CircleMarker(
        location=[data.iloc[i]['Lat'],data.iloc[i]['Long']],
        tooltip = "<h5>"+data.iloc[i].name+"</h5>"+
        "<li><b>GDP: </b>"+str(data.iloc[i]['GDP per capita'])+"</li>"+
        "<li><b>Social Support: </b>"+str(data.iloc[i]['Social support'])+"</li>"+
        "<li><b>Healthy life expectancy: </b>"+str(data.iloc[i]['Healthy life expectancy'])+"</li>"+
        "<li><b>Freedom to make life choices: </b>"+str(data.iloc[i]['Freedom to make life choices'])+"</li>",        
        radius = 3,
        color = '#008000',
        fill_color = '#008000',
        fill=True
    ).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
world_map.save('world_data_map.html')
# Import the Folium interactive html file


from IPython.display import HTML
HTML('<iframe src=world_data_map.html width=990 height=650></iframe>')
# Out:
# <iframe src=world_data_map.html width=990 height=650></iframe>

# %% [markdown]
# ### Section 5: Visualization of results using Seaborn.

# %% [markdown]
# **Task**: Based on the plot above, comment on the Indicators having strong relationship with COVID19 Infection?

# %% [markdown]
# __Hint:__
#  - Plotting GDP vs maximum Infection rate
#  - Plotting Social support vs maximum Infection rate
#  - Plotting Healthy life expectancy vs maximum Infection rate
#  - Plotting Freedom to make life choices vs maximum Infection rate

# %%
data_p = Corona_Data.join(happiness_data,how='inner')
data_p
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               915.0           0.350           0.517
# Albania                   141.0           0.947           0.848
# Algeria                   675.0           1.002           1.160
# Argentina                7663.0           1.092           1.432
# Armenia                   771.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                1150.0           0.960           1.427
# Vietnam                    50.0           0.741           1.346
# Yemen                     116.0           0.287           1.163
# Zambia                    915.0           0.578           1.058
# Zimbabwe                  490.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
# ...                              ...                           ...
# Venezuela                      0.805                         0.154
# Vietnam                        0.851                         0.543
# Yemen                          0.463                         0.143
# Zambia                         0.426                         0.431
# Zimbabwe                       0.433                         0.361
#
# [144 rows x 5 columns]

# %%
x_social = data_p['Social support']
x_GDP = data_p['GDP per capita']
x_Healthy = data_p['Healthy life expectancy']
x_freedom = data_p['Freedom to make life choices']

y = data_p['max_infection_rate']

sns.set_style("whitegrid")
sns.scatterplot(x_social, np.log(y));

# %%
sns.scatterplot(x_GDP, np.log(y));

# %%
sns.scatterplot(x_Healthy, np.log(y));

# %%
sns.scatterplot(x_freedom, np.log(y));

# %%
sns.swarmplot(x_social,  
             np.log(y))

# %% [markdown]
# Renaming of the column name was needed to get rid of spacing between the values

# %%
#sns.pairplot(data_p, hue='max_infection_rate');
sns.distplot(y,kde=True,hist=False);

# %%
sns.jointplot(x_social,y= np.log(y),data=data_p);

# %% [markdown]
# <h1> Thank you </h1>
